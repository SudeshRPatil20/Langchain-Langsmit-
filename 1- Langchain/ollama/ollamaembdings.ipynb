# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embdings=(
    OllamaEmbeddings(model="gemma:2b"model="gemma:2b")  #by defalt it uses llama 2 model
)

# %% [markdown]
# Ollama is an model that suports embding and used in Retrive Argumented Model. it is application fredly that supports combining text prompts with existing and others inshort we can say ollama is platform or technologi that allow us to use various model for emdeding our text in to vector form that are used in RAG system as example.

# %%
embdings
# Out:
# OllamaEmbeddings(base_url='http://localhost:11434', model='gemma:2b', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
r1=embdings.embed_documents(
    [
        "this is my new car whys my i am thinking like someones years are bunning"
    ]
) 




#(texts: List[str]) -> List[List[float]]
# texts
# The list of texts to embed.


# Embed documents using an Ollama deployed embeddin

# %%
len(r1[0])
# Out:
# 2048

# %%
embdings.embed_query("who bought the car?")
# Out:
# [-0.5047812461853027,
#  -0.08380850404500961,
#  0.7607005834579468,
#  0.6013312935829163,
#  1.1650328636169434,
#  0.38384246826171875,
#  1.0630340576171875,
#  -0.4622822105884552,
#  1.643873929977417,
#  -0.6543745994567871,
#  3.1494691371917725,
#  0.32605546712875366,
#  -1.469224452972412,
#  1.6611859798431396,
#  0.3537045419216156,
#  0.09570717066526413,
#  0.4452735483646393,
#  0.5466320514678955,
#  -1.5284944772720337,
#  -0.07519736140966415,
#  0.5916074514389038,
#  -0.44933879375457764,
#  0.43476739525794983,
#  -0.12057600915431976,
#  -0.3283740282058716,
#  -0.8848869800567627,
#  0.785596489906311,
#  -1.1559464931488037,
#  -0.7415807843208313,
#  -3.4892280101776123,
#  -0.2658017575740814,
#  0.5887851119041443,
#  0.32314276695251465,
#  0.6276496052742004,
#  1.134344220161438,
#  0.40820398926734924,
#  1.1905834674835205,
#  0.5174679756164551,
#  0.4092889428138733,
#  -1.5999130010604858,
#  -0.38943156599998474,
#  0.10061204433441162,
# ...
